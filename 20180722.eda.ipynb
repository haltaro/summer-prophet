# %% [markdown]
# # 140年分の東京の気温を分析
#
# [気象庁](http://www.data.jma.go.jp/gmd/risk/obsdl/index.php)のデータを分析する．
#
# ## 環境構築

# %%
# インラインにグラフ描画
# %matplotlib inline 
# 解像度を高める
# %config InlineBackend.figure_format = 'retina' 

# （本当はよくないけど）警告メッセージを無視する
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np # 数値計算
import pandas as pd # DataFrame
import matplotlib.pyplot as plt # グラフ描画
import seaborn as sns # グラフ描画設定
import json # jsonファイルの読み書き
import itertools # 組み込み関数．特にproductをよく使う
from datetime import datetime, timedelta # 日付
from tqdm import tqdm # forループの進捗状況確認

sns.set_style(style='ticks') # グラフスタイルの指定

# %%
import codecs # SJIS読み込み用

# %%
from fbprophet import Prophet

# %% [markdown]
# ## グローバル変数

# %%
read_path = 'data/raw/'

# %% [markdown]
# ## ファイル読み込み

# %%
years = range(1870, 2020, 10)

all_data = pd.DataFrame()

for year in tqdm(years):
    data_file = 'data_{}.csv'.format(year)
    
    # 普通にpd.read_csvすると読み込めない
    with codecs.open(read_path+data_file, "r", "Shift-JIS", "ignore") as f:
        # 先頭数行のデータは使用しない．
        data = pd.read_table(
            f, delimiter=",", skiprows=5, index_col=0, 
            usecols=[0, 1, 4, 7])
        
    # カラムの処理
    data.index = pd.to_datetime(data.index)
    data.columns = ['average', 'high', 'low']
    
    all_data = pd.concat([all_data, data])
# Out:
# 100%|██████████| 15/15 [00:00<00:00, 112.32it/s]

# %%
all_data.shape
# Out:
# (53528, 3)

# %%
all_data.average.isna().sum() / all_data.shape[0], all_data.average.isna().sum()
# Out:
# (0.023763264086085787, 1272)

# %% [markdown]
# 先頭の2%ちょいはデータなし．

# %%
# Nanのデータは削除
all_data = all_data.dropna(how='all')

# %%
all_data.shape
# Out:
# (52266, 3)

# %%
all_data.head()
# Out:
#             average  high   low
# 1875-06-10     20.5  24.5  16.4
# 1875-06-11     19.7  25.7  13.7
# 1875-06-12     20.7  25.1  16.3
# 1875-06-13     21.7  23.2  20.1
# 1875-06-15     19.3  21.8  16.8

# %%
all_data.tail()
# Out:
#             average  high   low
# 2018-07-17     29.9  34.8  26.9
# 2018-07-18     30.5  35.3  26.7
# 2018-07-19     29.9  34.8  26.6
# 2018-07-20     29.9  34.2  27.0
# 2018-07-21     30.5  34.9  26.9

# %% [markdown]
# ## 平均気温

# %%
plt.figure(figsize=(8, 6))
plt.plot(all_data.index, all_data.average, 'o', alpha=.1)
plt.xlabel('Date')
plt.ylabel('Average temparature')
# Out:
# Text(0,0.5,'Average temparature')

# %%
ave_data = pd.DataFrame()
ave_data['ds'] = all_data.index
ave_data['y'] = all_data.average.values

# %%
m = Prophet(weekly_seasonality=False)
m.fit(ave_data)
# Out:
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
# 将来30日間を予測
future = m.make_future_dataframe(periods=30)
forecast = m.predict(future)

# %%
_ = m.plot(forecast)
plt.xlim(future.ds.iloc[-365-30], future.ds.iloc[-1])
plt.xlabel('Date')
plt.ylabel('Average')
# Out:
# Text(65.125,0.5,'Average')

# %%
_ = m.plot_components(forecast)

# %%
forecast.iloc[-40:, [0, -1]]
# Out:
#               ds       yhat
# 52256 2018-07-12  26.344606
# 52257 2018-07-13  26.499637
# 52258 2018-07-14  26.653391
# 52259 2018-07-15  26.805163
# 52260 2018-07-16  26.954241
# 52261 2018-07-17  27.099913
# 52262 2018-07-18  27.241478
# 52263 2018-07-19  27.378260
# 52264 2018-07-20  27.509616
# 52265 2018-07-21  27.634945
# 52266 2018-07-22  27.753701
# 52267 2018-07-23  27.865395
# 52268 2018-07-24  27.969609
# 52269 2018-07-25  28.065998
# 52270 2018-07-26  28.154292
# 52271 2018-07-27  28.234305
# 52272 2018-07-28  28.305930
# 52273 2018-07-29  28.369142
# 52274 2018-07-30  28.423995
# 52275 2018-07-31  28.470619
# 52276 2018-08-01  28.509215
# 52277 2018-08-02  28.540044
# 52278 2018-08-03  28.563428
# 52279 2018-08-04  28.579732
# 52280 2018-08-05  28.589361
# 52281 2018-08-06  28.592744
# 52282 2018-08-07  28.590328
# 52283 2018-08-08  28.582563
# 52284 2018-08-09  28.569894
# 52285 2018-08-10  28.552747
# 52286 2018-08-11  28.531520
# 52287 2018-08-12  28.506575
# 52288 2018-08-13  28.478227
# 52289 2018-08-14  28.446736
# 52290 2018-08-15  28.412305
# 52291 2018-08-16  28.375070
# 52292 2018-08-17  28.335098
# 52293 2018-08-18  28.292391
# 52294 2018-08-19  28.246876
# 52295 2018-08-20  28.198416

# %% [markdown]
# ## 最高気温

# %%
plt.figure(figsize=(8, 6))
plt.plot(all_data.index, all_data.high, 'o', alpha=.1)
plt.xlabel('Date')
plt.ylabel('Max temparature')
# Out:
# Text(0,0.5,'Max temparature')

# %%
high_data = pd.DataFrame()
high_data['ds'] = all_data.index
high_data['y'] = all_data.high.values

# %%
m = Prophet(weekly_seasonality=False)
m.fit(high_data)
# Out:
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
# 将来30日間を予測
future = m.make_future_dataframe(periods=30)
forecast = m.predict(future)

# %%
_ = m.plot(forecast)
plt.xlim(future.ds.iloc[-365-30], future.ds.iloc[-1])
plt.xlabel('Date')
plt.ylabel('Max')
# Out:
# Text(65.375,0.5,'Max')

# %%
_ = m.plot_components(forecast)

# %%
forecast.iloc[-40:, [0, -1]]
# Out:
#               ds       yhat
# 53518 2018-07-12  29.953772
# 53519 2018-07-13  30.125824
# 53520 2018-07-14  30.296135
# 53521 2018-07-15  30.463950
# 53522 2018-07-16  30.628532
# 53523 2018-07-17  30.789168
# 53524 2018-07-18  30.945174
# 53525 2018-07-19  31.095906
# 53526 2018-07-20  31.240768
# 53527 2018-07-21  31.379213
# 53528 2018-07-22  31.510753
# 53529 2018-07-23  31.634960
# 53530 2018-07-24  31.751471
# 53531 2018-07-25  31.859988
# 53532 2018-07-26  31.960284
# 53533 2018-07-27  32.052194
# 53534 2018-07-28  32.135625
# 53535 2018-07-29  32.210543
# 53536 2018-07-30  32.276978
# 53537 2018-07-31  32.335016
# 53538 2018-08-01  32.384797
# 53539 2018-08-02  32.426505
# 53540 2018-08-03  32.460366
# 53541 2018-08-04  32.486640
# 53542 2018-08-05  32.505613
# 53543 2018-08-06  32.517591
# 53544 2018-08-07  32.522892
# 53545 2018-08-08  32.521837
# 53546 2018-08-09  32.514746
# 53547 2018-08-10  32.501927
# 53548 2018-08-11  32.483674
# 53549 2018-08-12  32.460254
# 53550 2018-08-13  32.431908
# 53551 2018-08-14  32.398844
# 53552 2018-08-15  32.361229
# 53553 2018-08-16  32.319193
# 53554 2018-08-17  32.272820
# 53555 2018-08-18  32.222149
# 53556 2018-08-19  32.167178
# 53557 2018-08-20  32.107856

# %% [markdown]
# ## 最低気温

# %%
plt.figure(figsize=(8, 6))
plt.plot(all_data.index, all_data.low, 'o', alpha=.1)
plt.xlabel('Date')
plt.ylabel('Min temparature')
# Out:
# Text(0,0.5,'Min temparature')

# %%
low_data = pd.DataFrame()
low_data['ds'] = all_data.index
low_data['y'] = all_data.low.values

# %%
m = Prophet(weekly_seasonality=False)
m.fit(low_data)
# Out:
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
# 将来30日間を予測
future = m.make_future_dataframe(periods=30)
forecast = m.predict(future)

# %%
_ = m.plot(forecast)
plt.xlim(future.ds.iloc[-365-30], future.ds.iloc[-1])
plt.xlabel('Date')
plt.ylabel('Min')
# Out:
# Text(59.5,0.5,'Min')

# %%
_ = m.plot_components(forecast)

# %%
forecast.iloc[-40:, [0, -1]]
# Out:
#               ds       yhat
# 53518 2018-07-12  23.569711
# 53519 2018-07-13  23.714654
# 53520 2018-07-14  23.859018
# 53521 2018-07-15  24.002169
# 53522 2018-07-16  24.143432
# 53523 2018-07-17  24.282102
# 53524 2018-07-18  24.417456
# 53525 2018-07-19  24.548771
# 53526 2018-07-20  24.675334
# 53527 2018-07-21  24.796459
# 53528 2018-07-22  24.911498
# 53529 2018-07-23  25.019855
# 53530 2018-07-24  25.121000
# 53531 2018-07-25  25.214475
# 53532 2018-07-26  25.299907
# 53533 2018-07-27  25.377013
# 53534 2018-07-28  25.445605
# 53535 2018-07-29  25.505594
# 53536 2018-07-30  25.556989
# 53537 2018-07-31  25.599898
# 53538 2018-08-01  25.634519
# 53539 2018-08-02  25.661139
# 53540 2018-08-03  25.680122
# 53541 2018-08-04  25.691901
# 53542 2018-08-05  25.696963
# 53543 2018-08-06  25.695842
# 53544 2018-08-07  25.689099
# 53545 2018-08-08  25.677306
# 53546 2018-08-09  25.661039
# 53547 2018-08-10  25.640853
# 53548 2018-08-11  25.617273
# 53549 2018-08-12  25.590780
# 53550 2018-08-13  25.561794
# 53551 2018-08-14  25.530668
# 53552 2018-08-15  25.497672
# 53553 2018-08-16  25.462992
# 53554 2018-08-17  25.426721
# 53555 2018-08-18  25.388853
# 53556 2018-08-19  25.349288
# 53557 2018-08-20  25.307830
